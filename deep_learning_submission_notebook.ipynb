# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Stanford Sentiment Treebank - Movie Review Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using keras Tokenizer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare==0.0.189
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aimodelshare==0.0.189
#   Downloading aimodelshare-0.0.189-py3-none-any.whl (967 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.8/967.8 kB 12.8 MB/s eta 0:00:00
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.0.1)
# Collecting tf2onnx
#   Downloading tf2onnx-1.14.0-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2.0.0+cu118)
# Collecting scikit-learn==1.2.1
#   Downloading scikit_learn-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 57.3 MB/s eta 0:00:00
# Collecting pydot==1.3.0
#   Downloading pydot-1.3.0-py2.py3-none-any.whl (18 kB)
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 kB 2.9 MB/s eta 0:00:00
# Collecting tensorflow==2.9.2
#   Downloading tensorflow-2.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 2.3 MB/s eta 0:00:00
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.6.3)
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 55.8 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2022.10.31)
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.2-py2.py3-none-any.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (5.9.4)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (0.12.2)
# Collecting boto3==1.26.69
#   Downloading boto3-1.26.69-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 14.6 MB/s eta 0:00:00
# Collecting skl2onnx>=1.14.0
#   Downloading skl2onnx-1.14.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 kB 29.4 MB/s eta 0:00:00
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 kB 9.7 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 83.8 MB/s eta 0:00:00
# Collecting importlib-resources==5.10.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting scipy==1.7.0
#   Downloading scipy-1.7.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 44.0 MB/s eta 0:00:00
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 18.3 MB/s eta 0:00:00
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 20.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting protobuf==3.19.6
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.1 MB/s eta 0:00:00
# Collecting botocore==1.29.82
#   Downloading botocore-1.29.82-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare==0.0.189) (0.40.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare==0.0.189) (1.16.0)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 9.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare==0.0.189) (1.26.15)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare==0.0.189) (2.8.2)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.9/dist-packages (from docker==5.0.0->aimodelshare==0.0.189) (2.27.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker==5.0.0->aimodelshare==0.0.189) (1.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources==5.10.0->aimodelshare==0.0.189) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare==0.0.189) (4.5.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare==0.0.189) (1.22.4)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.9/dist-packages (from pydot==1.3.0->aimodelshare==0.0.189) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare==0.0.189) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare==0.0.189) (3.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.4.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.32.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (16.0.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (67.6.1)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (3.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.53.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (3.3.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.7 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (23.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (2.2.0)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.7.0->aimodelshare==0.0.189) (1.11.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare==0.0.189) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare==0.0.189) (1.5.3)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8.1->aimodelshare==0.0.189) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8.1->aimodelshare==0.0.189) (16.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->seaborn>=0.11.2->aimodelshare==0.0.189) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (2.0.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 93.0 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (2.17.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (2.2.3)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.8.1->aimodelshare==0.0.189) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare==0.0.189) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (6.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (3.2.2)
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164822 sha256=216f5b5b9301b35b5579bc770aa835bebc4047c09197032146f529f6bf382144
#   Stored in directory: /root/.cache/pip/wheels/03/84/9a/0e7aa69b52bc9dc13ea25679c8d8f1dc11bc5b5289db23d9f3
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=2288e4dd32f097b7fd484c89267188f6a12a01faf4529c2370d99605565ef7a1
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=decd33488cdc2795a2811d1c9e51fab9478b1f95749ab90c32016c495bc7fdc3
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built Pympler wget fire
# Installing collected packages: wget, Pympler, keras, flatbuffers, tensorflow-estimator, tensorboard-data-server, shortuuid, scipy, PyJWT, pydot, protobuf, keras-preprocessing, jmespath, importlib-resources, humanfriendly, fire, scikit-learn, onnx, docker, coloredlogs, botocore, tf2onnx, s3transfer, onnxruntime, onnxconverter-common, google-auth-oauthlib, tensorboard, skl2onnx, keras2onnx, boto3, tensorflow, onnxmltools, aimodelshare
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pydot
#     Found existing installation: pydot 1.4.2
#     Uninstalling pydot-1.4.2:
#       Successfully uninstalled pydot-1.4.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.12.0
#     Uninstalling importlib-resources-5.12.0:
#       Successfully uninstalled importlib-resources-5.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.1
#     Uninstalling tensorboard-2.12.1:
#       Successfully uninstalled tensorboard-2.12.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires scipy>=1.8.0, but you have scipy 1.7.0 which is incompatible.
# Successfully installed PyJWT-2.6.0 Pympler-0.9 aimodelshare-0.0.189 boto3-1.26.69 botocore-1.29.82 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 flatbuffers-1.12 google-auth-oauthlib-0.4.6 humanfriendly-10.0 importlib-resources-5.10.0 jmespath-1.0.1 keras-2.9.0 keras-preprocessing-1.1.2 keras2onnx-1.7.0 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.2 onnxruntime-1.14.1 protobuf-3.19.6 pydot-1.3.0 s3transfer-0.6.0 scikit-learn-1.2.1 scipy-1.7.0 shortuuid-1.0.11 skl2onnx-1.14.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorflow-2.9.2 tensorflow-estimator-2.9.0 tf2onnx-1.14.0 wget-3.2

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/sst2_competition_data-repository:latest')
# Out:
# Downloading [=============================================>   ]
#
# Data downloaded successfully.

# %%
# Set up X_train, X_test, and y_train_labels objects
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=Warning)

X_train=pd.read_csv("sst2_competition_data/X_train.csv", squeeze=True)
X_test=pd.read_csv("sst2_competition_data/X_test.csv", squeeze=True)

y_train_labels=pd.read_csv("sst2_competition_data/y_train_labels.csv", squeeze=True)

# ohe encode Y data
y_train = pd.get_dummies(y_train_labels)

X_train.head()
# Out:
# 0    The Rock is destined to be the 21st Century 's...
# 1    The gorgeously elaborate continuation of `` Th...
# 2    Singer/composer Bryan Adams contributes a slew...
# 3                 Yet the act is still charming here .
# 4    Whether or not you 're enlightened by any of D...
# Name: text, dtype: object

# %% [markdown]
# ##2.   Preprocess data using keras tokenizer / Write and Save Preprocessor function

# %%
# This preprocessor function makes use of the tf.keras tokenizer

from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen=40, max_words=10000):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

print(preprocessor(X_train).shape)
print(preprocessor(X_test).shape)
# Out:
# (6920, 40)
# (1821, 40)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from tensorflow.keras.layers import SimpleRNN, LSTM
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Embedding(10000, 16, input_length=40))
model.add(LSTM(32, return_sequences=True, dropout=0.2))
model.add(LSTM(32, dropout=0.2))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_22 (Embedding)    (None, 40, 16)            160000
#
#  lstm_2 (LSTM)               (None, 40, 32)            6272
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_18 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 174,658
# Trainable params: 174,658
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 173/173 [==============================] - 9s 39ms/step - loss: 0.6326 - acc: 0.6380 - val_loss: 0.7061 - val_acc: 0.5679
# Epoch 2/10
# 173/173 [==============================] - 5s 27ms/step - loss: 0.4631 - acc: 0.7861 - val_loss: 0.5526 - val_acc: 0.7457
# Epoch 3/10
# 173/173 [==============================] - 5s 27ms/step - loss: 0.3562 - acc: 0.8452 - val_loss: 0.5478 - val_acc: 0.7579
# Epoch 4/10
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2913 - acc: 0.8763 - val_loss: 0.6796 - val_acc: 0.6987
# Epoch 5/10
# 173/173 [==============================] - 4s 26ms/step - loss: 0.2451 - acc: 0.9005 - val_loss: 0.6510 - val_acc: 0.6965
# Epoch 6/10
# 173/173 [==============================] - 4s 25ms/step - loss: 0.2127 - acc: 0.9147 - val_loss: 0.7128 - val_acc: 0.7059
# Epoch 7/10
# 173/173 [==============================] - 6s 32ms/step - loss: 0.1862 - acc: 0.9232 - val_loss: 0.7161 - val_acc: 0.7225
# Epoch 8/10
# 173/173 [==============================] - 5s 31ms/step - loss: 0.1646 - acc: 0.9342 - val_loss: 0.4671 - val_acc: 0.8201
# Epoch 9/10
# 173/173 [==============================] - 5s 27ms/step - loss: 0.1474 - acc: 0.9415 - val_loss: 0.6104 - val_acc: 0.7623
# Epoch 10/10
# 173/173 [==============================] - 5s 31ms/step - loss: 0.1364 - acc: 0.9471 - val_loss: 0.5890 - val_acc: 0.7558

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://rlxjxnoql9.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this specific Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 1s 9ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 382
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_a3d5b_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a3d5b_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a3d5b_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 92.4%, transparent 92.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a3d5b_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a3d5b_row0_col4, #T_a3d5b_row0_col5, #T_a3d5b_row0_col6, #T_a3d5b_row0_col7, #T_a3d5b_row0_col8, #T_a3d5b_row0_col9, #T_a3d5b_row0_col10, #T_a3d5b_row0_col11, #T_a3d5b_row0_col12, #T_a3d5b_row0_col13, #T_a3d5b_row0_col14, #T_a3d5b_row0_col15, #T_a3d5b_row0_col16, #T_a3d5b_row0_col17, #T_a3d5b_row0_col18, #T_a3d5b_row0_col19, #T_a3d5b_row0_col20, #T_a3d5b_row0_col21, #T_a3d5b_row0_col22, #T_a3d5b_row0_col23, #T_a3d5b_row0_col24, #T_a3d5b_row0_col25, #T_a3d5b_row0_col26, #T_a3d5b_row0_col27, #T_a3d5b_row0_col28, #T_a3d5b_row0_col29, #T_a3d5b_row0_col30, #T_a3d5b_row0_col31, #T_a3d5b_row0_col32, #T_a3d5b_row0_col33, #T_a3d5b_row1_col4, #T_a3d5b_row1_col5, #T_a3d5b_row1_col6, #T_a3d5b_row1_col7, #T_a3d5b_row1_col8, #T_a3d5b_row1_col9, #T_a3d5b_row1_col10, #T_a3d5b_row1_col11, #T_a3d5b_row1_col12, #T_a3d5b_row1_col13, #T_a3d5b_row1_col14, #T_a3d5b_row1_col15, #T_a3d5b_row1_col16, #T_a3d5b_row1_col17, #T_a3d5b_row1_col18, #T_a3d5b_row1_col19, #T_a3d5b_row1_col20, #T_a3d5b_row1_col21, #T_a3d5b_row1_col22, #T_a3d5b_row1_col23, #T_a3d5b_row1_col24, #T_a3d5b_row1_col25, #T_a3d5b_row1_col26, #T_a3d5b_row1_col27, #T_a3d5b_row1_col28, #T_a3d5b_row1_col29, #T_a3d5b_row1_col30, #T_a3d5b_row1_col31, #T_a3d5b_row1_col32, #T_a3d5b_row1_col33, #T_a3d5b_row2_col4, #T_a3d5b_row2_col5, #T_a3d5b_row2_col6, #T_a3d5b_row2_col7, #T_a3d5b_row2_col8, #T_a3d5b_row2_col9, #T_a3d5b_row2_col10, #T_a3d5b_row2_col11, #T_a3d5b_row2_col12, #T_a3d5b_row2_col13, #T_a3d5b_row2_col14, #T_a3d5b_row2_col15, #T_a3d5b_row2_col16, #T_a3d5b_row2_col17, #T_a3d5b_row2_col18, #T_a3d5b_row2_col19, #T_a3d5b_row2_col20, #T_a3d5b_row2_col21, #T_a3d5b_row2_col22, #T_a3d5b_row2_col23, #T_a3d5b_row2_col24, #T_a3d5b_row2_col25, #T_a3d5b_row2_col26, #T_a3d5b_row2_col27, #T_a3d5b_row2_col28, #T_a3d5b_row2_col29, #T_a3d5b_row2_col30, #T_a3d5b_row2_col31, #T_a3d5b_row2_col32, #T_a3d5b_row2_col33, #T_a3d5b_row3_col4, #T_a3d5b_row3_col5, #T_a3d5b_row3_col6, #T_a3d5b_row3_col7, #T_a3d5b_row3_col8, #T_a3d5b_row3_col9, #T_a3d5b_row3_col10, #T_a3d5b_row3_col11, #T_a3d5b_row3_col12, #T_a3d5b_row3_col13, #T_a3d5b_row3_col14, #T_a3d5b_row3_col15, #T_a3d5b_row3_col16, #T_a3d5b_row3_col17, #T_a3d5b_row3_col18, #T_a3d5b_row3_col19, #T_a3d5b_row3_col20, #T_a3d5b_row3_col21, #T_a3d5b_row3_col22, #T_a3d5b_row3_col23, #T_a3d5b_row3_col24, #T_a3d5b_row3_col25, #T_a3d5b_row3_col26, #T_a3d5b_row3_col27, #T_a3d5b_row3_col28, #T_a3d5b_row3_col29, #T_a3d5b_row3_col30, #T_a3d5b_row3_col31, #T_a3d5b_row3_col32, #T_a3d5b_row3_col33, #T_a3d5b_row4_col4, #T_a3d5b_row4_col5, #T_a3d5b_row4_col6, #T_a3d5b_row4_col7, #T_a3d5b_row4_col8, #T_a3d5b_row4_col9, #T_a3d5b_row4_col10, #T_a3d5b_row4_col11, #T_a3d5b_row4_col12, #T_a3d5b_row4_col13, #T_a3d5b_row4_col14, #T_a3d5b_row4_col15, #T_a3d5b_row4_col16, #T_a3d5b_row4_col17, #T_a3d5b_row4_col18, #T_a3d5b_row4_col19, #T_a3d5b_row4_col20, #T_a3d5b_row4_col21, #T_a3d5b_row4_col22, #T_a3d5b_row4_col23, #T_a3d5b_row4_col24, #T_a3d5b_row4_col25, #T_a3d5b_row4_col26, #T_a3d5b_row4_col27, #T_a3d5b_row4_col28, #T_a3d5b_row4_col29, #T_a3d5b_row4_col30, #T_a3d5b_row4_col31, #T_a3d5b_row4_col32, #T_a3d5b_row4_col33, #T_a3d5b_row5_col4, #T_a3d5b_row5_col5, #T_a3d5b_row5_col6, #T_a3d5b_row5_col7, #T_a3d5b_row5_col8, #T_a3d5b_row5_col9, #T_a3d5b_row5_col10, #T_a3d5b_row5_col11, #T_a3d5b_row5_col12, #T_a3d5b_row5_col13, #T_a3d5b_row5_col14, #T_a3d5b_row5_col15, #T_a3d5b_row5_col16, #T_a3d5b_row5_col17, #T_a3d5b_row5_col18, #T_a3d5b_row5_col19, #T_a3d5b_row5_col20, #T_a3d5b_row5_col21, #T_a3d5b_row5_col22, #T_a3d5b_row5_col23, #T_a3d5b_row5_col24, #T_a3d5b_row5_col25, #T_a3d5b_row5_col26, #T_a3d5b_row5_col27, #T_a3d5b_row5_col28, #T_a3d5b_row5_col29, #T_a3d5b_row5_col30, #T_a3d5b_row5_col31, #T_a3d5b_row5_col32, #T_a3d5b_row5_col33, #T_a3d5b_row6_col4, #T_a3d5b_row6_col5, #T_a3d5b_row6_col6, #T_a3d5b_row6_col7, #T_a3d5b_row6_col8, #T_a3d5b_row6_col9, #T_a3d5b_row6_col10, #T_a3d5b_row6_col11, #T_a3d5b_row6_col12, #T_a3d5b_row6_col13, #T_a3d5b_row6_col14, #T_a3d5b_row6_col15, #T_a3d5b_r ...

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop

model2 = Sequential()
model2.add(layers.Embedding(10000, 16, input_length=40))
model2.add(layers.Conv1D(32, 4, activation='relu')) 
model2.add(layers.MaxPooling1D(3)) 
model2.add(layers.Conv1D(32, 4, activation='relu'))
model2.add(layers.GlobalMaxPooling1D())
model2.add(Dense(2, activation='softmax'))

model2.compile(optimizer=RMSprop(lr=1e-4), loss='binary_crossentropy', metrics=['acc'])
history = model2.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 44/44 [==============================] - 2s 20ms/step - loss: 0.6886 - acc: 0.6124 - val_loss: 0.7179 - val_acc: 0.1488
# Epoch 2/10
# 44/44 [==============================] - 1s 14ms/step - loss: 0.6825 - acc: 0.6149 - val_loss: 0.7400 - val_acc: 0.1488
# Epoch 3/10
# 44/44 [==============================] - 1s 13ms/step - loss: 0.6766 - acc: 0.6149 - val_loss: 0.7669 - val_acc: 0.1488
# Epoch 4/10
# 44/44 [==============================] - 1s 15ms/step - loss: 0.6714 - acc: 0.6149 - val_loss: 0.7941 - val_acc: 0.1488
# Epoch 5/10
# 44/44 [==============================] - 1s 15ms/step - loss: 0.6673 - acc: 0.6149 - val_loss: 0.8215 - val_acc: 0.1488
# Epoch 6/10
# 44/44 [==============================] - 1s 11ms/step - loss: 0.6644 - acc: 0.6149 - val_loss: 0.8429 - val_acc: 0.1488
# Epoch 7/10
# 44/44 [==============================] - 0s 11ms/step - loss: 0.6624 - acc: 0.6149 - val_loss: 0.8569 - val_acc: 0.1488
# Epoch 8/10
# 44/44 [==============================] - 1s 11ms/step - loss: 0.6608 - acc: 0.6149 - val_loss: 0.8688 - val_acc: 0.1488
# Epoch 9/10
# 44/44 [==============================] - 1s 12ms/step - loss: 0.6593 - acc: 0.6149 - val_loss: 0.8754 - val_acc: 0.1488
# Epoch 10/10
# 44/44 [==============================] - 0s 11ms/step - loss: 0.6577 - acc: 0.6149 - val_loss: 0.8763 - val_acc: 0.1488

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_column_index=model2.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 0s 3ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 380
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Compare two or more models 
data=mycompetition.compare_models([1, 2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_d9ee1 caption {
#   color: black;
#   font-size: 18px;
# }
# #T_d9ee1_row0_col0, #T_d9ee1_row0_col3 {
#   background: #b3e2cd;
#   color: black;
#   color: black;
# }
# #T_d9ee1_row0_col1, #T_d9ee1_row0_col2, #T_d9ee1_row0_col4, #T_d9ee1_row0_col5, #T_d9ee1_row1_col1, #T_d9ee1_row1_col2, #T_d9ee1_row1_col4, #T_d9ee1_row1_col5, #T_d9ee1_row2_col1, #T_d9ee1_row2_col2, #T_d9ee1_row2_col4, #T_d9ee1_row2_col5, #T_d9ee1_row3_col0, #T_d9ee1_row3_col1, #T_d9ee1_row3_col2, #T_d9ee1_row3_col4, #T_d9ee1_row3_col5, #T_d9ee1_row4_col0, #T_d9ee1_row4_col1, #T_d9ee1_row4_col2, #T_d9ee1_row4_col4, #T_d9ee1_row4_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_d9ee1_row1_col0, #T_d9ee1_row3_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_d9ee1_row1_col3, #T_d9ee1_row2_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_d9ee1_row2_col0, #T_d9ee1_row4_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_d9ee1">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9ee1_level0_col0" class="col_heading level0 col0" >Model_1_Layer</th>
#       <th id="T_d9ee1_level0_col1" class="col_heading level0 col1" >Model_1_Shape</th>
#       <th id="T_d9ee1_level0_col2" class="col_heading level0 col2" >Model_1_Params</th>
#       <th id="T_d9ee1_level0_col3" class="col_heading level0 col3" >Model_2_Layer</th>
#       <th id="T_d9ee1_level0_col4" class="col_heading level0 col4" >Model_2_Shape</th>
#       <th id="T_d9ee1_level0_col5" class="col_heading level0 col5" >Model_2_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9ee1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9ee1_row0_col0" class="data row0 col0" >Embedding</td>
#       <td id="T_d9ee1_row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#       <td id="T_d9ee1_row0_col2" class="data row0 col2" >160000.000000</td>
#       <td id="T_d9ee1_row0_col3" class="data row0 col3" >Embedding</td>
#       <td id="T_d9ee1_row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#       <td id="T_d9ee1_row0_col5" class="data row0 col5" >160000</td>
#     </tr>
#     <tr>
#       <th id="T_d9ee1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9ee1_row1_col0" class="data row1 col0" >Flatten</td>
#       <td id="T_d9ee1_row1_col1" class="data row1 col1" >[None, 640]</td>
#       <td id="T_d9ee1_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_d9ee1_row1_col3" class="data row1 col3" >LSTM</td>
#       <td id="T_d9ee1_row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#       <td id="T_d9ee1_row1_col5" class="data row1 col5" >6272</td>
#     </tr>
#     <tr>
#       <th id="T_d9ee1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9ee1_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_d9ee1_row2_col1" class="data row2 col1" >[None, 2]</td>
#       <td id="T_d9ee1_row2_col2" class="data row2 col2" >1282.000000</td>
#       <td id="T_d9ee1_row2_col3" class="data row2 col3" >LSTM</td>
#       <td id="T_d9ee1_row2_col4" class="data row2 col4" >[None, 32]</td>
#       <td id="T_d9ee1_row2_col5" class="data row2 col5" >8320</td>
#     </tr>
#     <tr>
#       <th id="T_d9ee1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9ee1_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_d9ee1_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_d9ee1_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_d9ee1_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_d9ee1_row3_col4" class="data row3 col4" >[None, 32]</td>
#       <td id="T_d9ee1_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9ee1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9ee1_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_d9ee1_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_d9ee1_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_d9ee1_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_d9ee1_row4_col4" class="data row4 col4" >[None, 2]</td>
#       <td id="T_d9ee1_row4_col5" class="data row4 col5" >66</td>
#     </tr>
#   </tbody>
# </table>

# %%
! wget http://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Out:
# --2023-04-18 04:48:04--  http://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/wordvecs/glove.6B.zip [following]
# --2023-04-18 04:48:04--  https://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip [following]
# --2023-04-18 04:48:04--  https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182753 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.1’
#
# glove.6B.zip.1      100%[===================>] 822.24M  5.09MB/s    in 2m 39s
#
# 2023-04-18 04:50:44 (5.16 MB/s) - ‘glove.6B.zip.1’ saved [862182753/862182753]

# %%
! unzip glove.6B.zip.1
# Out:
# Archive:  glove.6B.zip.1
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
#   inflating: glove.6B.50d.txt

# %%
# Extract embedding data for 100 feature embedding matrix
import os
glove_dir = os.getcwd()

embeddings_index = {}
f = open(os.path.join(glove_dir, 'glove.6B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400001 word vectors.

# %%
# Build embedding matrix
embedding_dim = 100 # change if you use txt files using larger number of features
max_words = 10000
maxlen = 40
word_index = tokenizer.word_index

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if i < max_words:
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector

# %%
import tensorflow as tf
model3 = tf.keras.Sequential()
model3.add(tf.keras.layers.Embedding(max_words, embedding_dim, input_length=maxlen))
model3.add(tf.keras.layers.Flatten())
model3.add(tf.keras.layers.Dense(32, activation='relu'))
model3.add(tf.keras.layers.Dense(2, activation='sigmoid'))
model3.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_26 (Embedding)    (None, 40, 100)           1000000
#
#  flatten_5 (Flatten)         (None, 4000)              0
#
#  dense_25 (Dense)            (None, 32)                128032
#
#  dense_26 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 1,128,098
# Trainable params: 1,128,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.layers[0].set_weights([embedding_matrix])
model3.layers[0].trainable = False



model3.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model3.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
model3.save_weights('pre_trained_glove_model.h5')
# Out:
# Epoch 1/10
# 173/173 [==============================] - 2s 7ms/step - loss: 0.6260 - acc: 0.6499 - val_loss: 0.8037 - val_acc: 0.5043
# Epoch 2/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.5072 - acc: 0.7469 - val_loss: 0.6408 - val_acc: 0.6857
# Epoch 3/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.4302 - acc: 0.8027 - val_loss: 0.7822 - val_acc: 0.6113
# Epoch 4/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.3659 - acc: 0.8412 - val_loss: 0.9526 - val_acc: 0.5672
# Epoch 5/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.2971 - acc: 0.8766 - val_loss: 0.6740 - val_acc: 0.7030
# Epoch 6/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.2384 - acc: 0.9082 - val_loss: 1.0340 - val_acc: 0.5896
# Epoch 7/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.1810 - acc: 0.9400 - val_loss: 0.7118 - val_acc: 0.7305
# Epoch 8/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.1330 - acc: 0.9612 - val_loss: 0.8839 - val_acc: 0.6936
# Epoch 9/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.0972 - acc: 0.9762 - val_loss: 0.8612 - val_acc: 0.7283
# Epoch 10/10
# 173/173 [==============================] - 1s 4ms/step - loss: 0.0718 - acc: 0.9823 - val_loss: 1.1021 - val_acc: 0.6850

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model3, framework='keras',
                          transfer_learning=True,
                          deep_learning=True)

with open("model3.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=model3.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model3.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 0s 1ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 389
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_037c2_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_037c2_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_037c2_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 92.4%, transparent 92.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_037c2_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_037c2_row0_col4, #T_037c2_row0_col5, #T_037c2_row0_col6, #T_037c2_row0_col7, #T_037c2_row0_col8, #T_037c2_row0_col9, #T_037c2_row0_col10, #T_037c2_row0_col11, #T_037c2_row0_col12, #T_037c2_row0_col13, #T_037c2_row0_col14, #T_037c2_row0_col15, #T_037c2_row0_col16, #T_037c2_row0_col17, #T_037c2_row0_col18, #T_037c2_row0_col19, #T_037c2_row0_col20, #T_037c2_row0_col21, #T_037c2_row0_col22, #T_037c2_row0_col23, #T_037c2_row0_col24, #T_037c2_row0_col25, #T_037c2_row0_col26, #T_037c2_row0_col27, #T_037c2_row0_col28, #T_037c2_row0_col29, #T_037c2_row0_col30, #T_037c2_row0_col31, #T_037c2_row0_col32, #T_037c2_row0_col33, #T_037c2_row1_col4, #T_037c2_row1_col5, #T_037c2_row1_col6, #T_037c2_row1_col7, #T_037c2_row1_col8, #T_037c2_row1_col9, #T_037c2_row1_col10, #T_037c2_row1_col11, #T_037c2_row1_col12, #T_037c2_row1_col13, #T_037c2_row1_col14, #T_037c2_row1_col15, #T_037c2_row1_col16, #T_037c2_row1_col17, #T_037c2_row1_col18, #T_037c2_row1_col19, #T_037c2_row1_col20, #T_037c2_row1_col21, #T_037c2_row1_col22, #T_037c2_row1_col23, #T_037c2_row1_col24, #T_037c2_row1_col25, #T_037c2_row1_col26, #T_037c2_row1_col27, #T_037c2_row1_col28, #T_037c2_row1_col29, #T_037c2_row1_col30, #T_037c2_row1_col31, #T_037c2_row1_col32, #T_037c2_row1_col33, #T_037c2_row2_col4, #T_037c2_row2_col5, #T_037c2_row2_col6, #T_037c2_row2_col7, #T_037c2_row2_col8, #T_037c2_row2_col9, #T_037c2_row2_col10, #T_037c2_row2_col11, #T_037c2_row2_col12, #T_037c2_row2_col13, #T_037c2_row2_col14, #T_037c2_row2_col15, #T_037c2_row2_col16, #T_037c2_row2_col17, #T_037c2_row2_col18, #T_037c2_row2_col19, #T_037c2_row2_col20, #T_037c2_row2_col21, #T_037c2_row2_col22, #T_037c2_row2_col23, #T_037c2_row2_col24, #T_037c2_row2_col25, #T_037c2_row2_col26, #T_037c2_row2_col27, #T_037c2_row2_col28, #T_037c2_row2_col29, #T_037c2_row2_col30, #T_037c2_row2_col31, #T_037c2_row2_col32, #T_037c2_row2_col33, #T_037c2_row3_col4, #T_037c2_row3_col5, #T_037c2_row3_col6, #T_037c2_row3_col7, #T_037c2_row3_col8, #T_037c2_row3_col9, #T_037c2_row3_col10, #T_037c2_row3_col11, #T_037c2_row3_col12, #T_037c2_row3_col13, #T_037c2_row3_col14, #T_037c2_row3_col15, #T_037c2_row3_col16, #T_037c2_row3_col17, #T_037c2_row3_col18, #T_037c2_row3_col19, #T_037c2_row3_col20, #T_037c2_row3_col21, #T_037c2_row3_col22, #T_037c2_row3_col23, #T_037c2_row3_col24, #T_037c2_row3_col25, #T_037c2_row3_col26, #T_037c2_row3_col27, #T_037c2_row3_col28, #T_037c2_row3_col29, #T_037c2_row3_col30, #T_037c2_row3_col31, #T_037c2_row3_col32, #T_037c2_row3_col33, #T_037c2_row4_col4, #T_037c2_row4_col5, #T_037c2_row4_col6, #T_037c2_row4_col7, #T_037c2_row4_col8, #T_037c2_row4_col9, #T_037c2_row4_col10, #T_037c2_row4_col11, #T_037c2_row4_col12, #T_037c2_row4_col13, #T_037c2_row4_col14, #T_037c2_row4_col15, #T_037c2_row4_col16, #T_037c2_row4_col17, #T_037c2_row4_col18, #T_037c2_row4_col19, #T_037c2_row4_col20, #T_037c2_row4_col21, #T_037c2_row4_col22, #T_037c2_row4_col23, #T_037c2_row4_col24, #T_037c2_row4_col25, #T_037c2_row4_col26, #T_037c2_row4_col27, #T_037c2_row4_col28, #T_037c2_row4_col29, #T_037c2_row4_col30, #T_037c2_row4_col31, #T_037c2_row4_col32, #T_037c2_row4_col33, #T_037c2_row5_col4, #T_037c2_row5_col5, #T_037c2_row5_col6, #T_037c2_row5_col7, #T_037c2_row5_col8, #T_037c2_row5_col9, #T_037c2_row5_col10, #T_037c2_row5_col11, #T_037c2_row5_col12, #T_037c2_row5_col13, #T_037c2_row5_col14, #T_037c2_row5_col15, #T_037c2_row5_col16, #T_037c2_row5_col17, #T_037c2_row5_col18, #T_037c2_row5_col19, #T_037c2_row5_col20, #T_037c2_row5_col21, #T_037c2_row5_col22, #T_037c2_row5_col23, #T_037c2_row5_col24, #T_037c2_row5_col25, #T_037c2_row5_col26, #T_037c2_row5_col27, #T_037c2_row5_col28, #T_037c2_row5_col29, #T_037c2_row5_col30, #T_037c2_row5_col31, #T_037c2_row5_col32, #T_037c2_row5_col33, #T_037c2_row6_col4, #T_037c2_row6_col5, #T_037c2_row6_col6, #T_037c2_row6_col7, #T_037c2_row6_col8, #T_037c2_row6_col9, #T_037c2_row6_col10, #T_037c2_row6_col11, #T_037c2_row6_col12, #T_037c2_row6_col13, #T_037c2_row6_col14, #T_037c2_row6_col15, #T_037c2_r ...

# %%
# Compare two or more models
data=mycompetition.compare_models([1, 2, 3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_cdc57 caption {
#   color: black;
#   font-size: 18px;
# }
# #T_cdc57_row0_col0, #T_cdc57_row0_col3, #T_cdc57_row0_col6 {
#   background: #b3e2cd;
#   color: black;
#   color: black;
# }
# #T_cdc57_row0_col1, #T_cdc57_row0_col2, #T_cdc57_row0_col4, #T_cdc57_row0_col5, #T_cdc57_row0_col7, #T_cdc57_row0_col8, #T_cdc57_row1_col1, #T_cdc57_row1_col2, #T_cdc57_row1_col4, #T_cdc57_row1_col5, #T_cdc57_row1_col7, #T_cdc57_row1_col8, #T_cdc57_row2_col1, #T_cdc57_row2_col2, #T_cdc57_row2_col4, #T_cdc57_row2_col5, #T_cdc57_row2_col7, #T_cdc57_row2_col8, #T_cdc57_row3_col0, #T_cdc57_row3_col1, #T_cdc57_row3_col2, #T_cdc57_row3_col4, #T_cdc57_row3_col5, #T_cdc57_row3_col7, #T_cdc57_row3_col8, #T_cdc57_row4_col0, #T_cdc57_row4_col1, #T_cdc57_row4_col2, #T_cdc57_row4_col4, #T_cdc57_row4_col5, #T_cdc57_row4_col6, #T_cdc57_row4_col7, #T_cdc57_row4_col8 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_cdc57_row1_col0, #T_cdc57_row2_col6, #T_cdc57_row3_col3 {
#   background: nan;
#   color: black;
#   color: black;
# }
# #T_cdc57_row1_col3, #T_cdc57_row1_col6, #T_cdc57_row2_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_cdc57_row2_col0, #T_cdc57_row3_col6, #T_cdc57_row4_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_cdc57">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdc57_level0_col0" class="col_heading level0 col0" >Model_1_Layer</th>
#       <th id="T_cdc57_level0_col1" class="col_heading level0 col1" >Model_1_Shape</th>
#       <th id="T_cdc57_level0_col2" class="col_heading level0 col2" >Model_1_Params</th>
#       <th id="T_cdc57_level0_col3" class="col_heading level0 col3" >Model_2_Layer</th>
#       <th id="T_cdc57_level0_col4" class="col_heading level0 col4" >Model_2_Shape</th>
#       <th id="T_cdc57_level0_col5" class="col_heading level0 col5" >Model_2_Params</th>
#       <th id="T_cdc57_level0_col6" class="col_heading level0 col6" >Model_3_Layer</th>
#       <th id="T_cdc57_level0_col7" class="col_heading level0 col7" >Model_3_Shape</th>
#       <th id="T_cdc57_level0_col8" class="col_heading level0 col8" >Model_3_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdc57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdc57_row0_col0" class="data row0 col0" >Embedding</td>
#       <td id="T_cdc57_row0_col1" class="data row0 col1" >[None, 40, 16]</td>
#       <td id="T_cdc57_row0_col2" class="data row0 col2" >160000.000000</td>
#       <td id="T_cdc57_row0_col3" class="data row0 col3" >Embedding</td>
#       <td id="T_cdc57_row0_col4" class="data row0 col4" >[None, 40, 16]</td>
#       <td id="T_cdc57_row0_col5" class="data row0 col5" >160000</td>
#       <td id="T_cdc57_row0_col6" class="data row0 col6" >Embedding</td>
#       <td id="T_cdc57_row0_col7" class="data row0 col7" >[None, 40, 16]</td>
#       <td id="T_cdc57_row0_col8" class="data row0 col8" >160000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cdc57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdc57_row1_col0" class="data row1 col0" >Flatten</td>
#       <td id="T_cdc57_row1_col1" class="data row1 col1" >[None, 640]</td>
#       <td id="T_cdc57_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_cdc57_row1_col3" class="data row1 col3" >LSTM</td>
#       <td id="T_cdc57_row1_col4" class="data row1 col4" >[None, 40, 32]</td>
#       <td id="T_cdc57_row1_col5" class="data row1 col5" >6272</td>
#       <td id="T_cdc57_row1_col6" class="data row1 col6" >LSTM</td>
#       <td id="T_cdc57_row1_col7" class="data row1 col7" >[None, 40, 256]</td>
#       <td id="T_cdc57_row1_col8" class="data row1 col8" >279552.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cdc57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdc57_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_cdc57_row2_col1" class="data row2 col1" >[None, 2]</td>
#       <td id="T_cdc57_row2_col2" class="data row2 col2" >1282.000000</td>
#       <td id="T_cdc57_row2_col3" class="data row2 col3" >LSTM</td>
#       <td id="T_cdc57_row2_col4" class="data row2 col4" >[None, 32]</td>
#       <td id="T_cdc57_row2_col5" class="data row2 col5" >8320</td>
#       <td id="T_cdc57_row2_col6" class="data row2 col6" >Flatten</td>
#       <td id="T_cdc57_row2_col7" class="data row2 col7" >[None, 10240]</td>
#       <td id="T_cdc57_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cdc57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdc57_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_cdc57_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_cdc57_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_cdc57_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_cdc57_row3_col4" class="data row3 col4" >[None, 32]</td>
#       <td id="T_cdc57_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_cdc57_row3_col6" class="data row3 col6" >Dense</td>
#       <td id="T_cdc57_row3_col7" class="data row3 col7" >[None, 2]</td>
#       <td id="T_cdc57_row3_col8" class="data row3 col8" >20482.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cdc57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdc57_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_cdc57_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_cdc57_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_cdc57_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_cdc57_row4_col4" class="data row4 col4" >[None, 2]</td>
#       <td id="T_cdc57_row4_col5" class="data row4 col5" >66</td>
#       <td id="T_cdc57_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_cdc57_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_cdc57_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **1. Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.**
#
# SST data contains fully labeled parse tree having the sentimental score for each phrase. Building a predictive model like this could help companies or individuals to understand others' feelings. Restaurant could adjust their business model base on the reviews customer left. Investors could adjust their investment model based on the comments or reactions the public has toward current economy form etc.

# %% [markdown]
# **2. Discuss which models performed better and point out relevant hyper-parameter values for successful models.**
#
# The best model had flatten layers, lstm layers, dense layers. The activation function is also important, probably playing a key role here. I used softmax and tanh.
